# %% [markdown]
# <a href="https://colab.research.google.com/github/qbarger/byu-cs474/blob/master/lab5_generalization_regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/porterjenkins/byu-cs474/blob/master/lab5_generalization_regularization.ipynb)

# %% [markdown]
# # Lab 5: Overfitting, Generalization, and Regularization

# %% [markdown]
# ---
#
# ## Objectives

# %% [markdown]
# *   Understand how to accurately measure generalization performance of deep networks
# *   Gain intuition into the bias-variance trade-off and the double descent phenomenon
# *   Investigate properties of high dimensional spaces and better understand the "curse of dimensionality"

# %% [markdown]
# ---
#
# ## Deliverable

# %% [markdown]
# You will turn in a completed version of notebook to Canvas/Learning Suite.  In various places you will see the words "TO DO". Follow the instructions at these places and write code to complete the instructions

# %% [markdown]
# ---
#
# ## Notes

# %% [markdown]
# You will need a GPU instance for this lab.
#
# Students can sign up for a free Colab Pro subscription. This is recommended if you do not have your own GPU.

# %% [markdown]
# ---
#
# # Q1) Understanding Generalization

# %% [markdown]
# In this question, we will use the [MNIST1D dataset](https://github.com/greydanus/mnist1d) to reproduce Figure 8.2 from Prince.

# %%
# Run this if you're in Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-x_hn3ajt
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-x_hn3ajt
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=30c360ec7f992fd1e41bb4ad5a8fb78cdbf49eedc7b155d01f24852b19856d04
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1stdudw0/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code. The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
# !mkdir ./sample_data

args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./sample_data/mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# mkdir: cannot create directory ‘./sample_data’: File exists
# Did or could not load data from ./sample_data/mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions

# %% [markdown]
# ---
#
# ## Part 1.a)

# %% [markdown]
# **TODO:** Define a PyTorch model with two hidden layers of size 100 And ReLU activations between them

# %%
# Your code here (see Figure 7.8 of book for help)
model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o)
)

# %% [markdown]
# **TODO:** Initialize the parameters with He initialization

# %%
def weights_init(layer_in):
    # TODO: Replace this line (see figure 7.8 of Prince for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
def train_model(model, data_loader, n_epoch=50):

    # Initialize model weights
    model.apply(weights_init)

    # store the loss and the % correct at each epoch
    losses_train = np.zeros((n_epoch))
    errors_train = np.zeros((n_epoch))
    losses_test = np.zeros((n_epoch))
    errors_test = np.zeros((n_epoch))

    # choose cross entropy loss function (equation 5.24)
    loss_function = torch.nn.CrossEntropyLoss()
    # construct SGD optimizer and initialize learning rate and momentum
    optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
    # object that decreases learning rate by half every 10 epochs
    scheduler = StepLR(optimizer, step_size=10, gamma=0.5)


    for epoch in range(n_epoch):
      # loop over batches
      for i, batch in enumerate(data_loader):
        # retrieve inputs and labels for this batch
        x_batch, y_batch = batch
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward pass -- calculate model output
        pred = model(x_batch)
        # compute the loss
        loss = loss_function(pred, y_batch)
        # backward pass
        loss.backward()
        # SGD update
        optimizer.step()

      # Run whole dataset to get statistics -- normally wouldn't do this
      pred_train = model(x_train)
      pred_test = model(x_test)
      _, predicted_train_class = torch.max(pred_train.data, 1)
      _, predicted_test_class = torch.max(pred_test.data, 1)
      errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
      errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
      losses_train[epoch] = loss_function(pred_train, y_train).item()
      losses_test[epoch]= loss_function(pred_test, y_test).item()
      print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

      # tell scheduler to consider updating learning rate
      scheduler.step()

    return errors_train, errors_test, losses_train, losses_test

# %%
def plot_results(errors_train, errors_test, losses_train, losses_test, n_epoch=50):

    # Plot the results
    fig, ax = plt.subplots()
    ax.plot(errors_train,'r-',label='train')
    ax.plot(errors_test,'b-',label='test')
    ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
    ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
    ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
    ax.legend()
    plt.show()

    # Plot the results
    fig, ax = plt.subplots()
    ax.plot(losses_train,'r-',label='train')
    ax.plot(losses_test,'b-',label='test')
    ax.set_xlim(0,n_epoch)
    ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
    ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
    ax.legend()
    plt.show()

# %% [markdown]
# **TODO:** Train your model for 50 epochs

# %%
# Your code here
errors_train, errors_test, losses_train, losses_test = train_model(model, data_loader, 50)
# Out:
# Epoch     0, train loss 1.629055, train error 65.20,  test loss 1.742907, test error 71.90
# Epoch     1, train loss 1.316879, train error 49.40,  test loss 1.476960, test error 59.20
# Epoch     2, train loss 1.116082, train error 41.35,  test loss 1.352347, test error 54.10
# Epoch     3, train loss 0.980245, train error 35.93,  test loss 1.247931, test error 49.00
# Epoch     4, train loss 0.884324, train error 31.72,  test loss 1.186758, test error 47.40
# Epoch     5, train loss 0.804193, train error 28.28,  test loss 1.178890, test error 44.00
# Epoch     6, train loss 0.710853, train error 25.30,  test loss 1.127532, test error 44.50
# Epoch     7, train loss 0.611776, train error 20.25,  test loss 1.098426, test error 42.80
# Epoch     8, train loss 0.574786, train error 18.78,  test loss 1.132255, test error 42.60
# Epoch     9, train loss 0.516780, train error 17.05,  test loss 1.139110, test error 41.60
# Epoch    10, train loss 0.427656, train error 12.62,  test loss 1.107992, test error 41.10
# Epoch    11, train loss 0.377972, train error 10.72,  test loss 1.076615, test error 38.80
# Epoch    12, train loss 0.348046, train error 9.62,  test loss 1.113467, test error 38.90
# Epoch    13, train loss 0.318182, train error 8.57,  test loss 1.130304, test error 39.50
# Epoch    14, train loss 0.294980, train error 7.57,  test loss 1.158908, test error 40.00
# Epoch    15, train loss 0.270446, train error 6.53,  test loss 1.155796, test error 38.70
# Epoch    16, train loss 0.249139, train error 6.00,  test loss 1.178218, test error 37.90
# Epoch    17, train loss 0.225452, train error 4.68,  test loss 1.169696, test error 38.40
# Epoch    18, train loss 0.196839, train error 3.45,  test loss 1.207197, test error 38.00
# Epoch    19, train loss 0.199571, train error 3.97,  test loss 1.258834, test error 38.30
# Epoch    20, train loss 0.160491, train error 2.18,  test loss 1.198820, test error 36.30
# Epoch    21, train loss 0.148305, train error 1.65,  test loss 1.219609, test error 37.40
# Epoch    22, train loss 0.140990, train error 1.43,  test loss 1.223420, test error 37.40
# Epoch    23, train loss 0.133230, train error 1.22,  test loss 1.234437, test error 37.50
# Epoch    24, train loss 0.128824, train error 1.20,  test loss 1.261734, test error 37.80
# Epoch    25, train loss 0.120358, train error 0.88,  test loss 1.257035, test error 37.40
# Epoch    26, train loss 0.113276, train error 0.65,  test loss 1.276931, test error 38.10
# Epoch    27, train loss 0.107827, train error 0.72,  test loss 1.280777, test error 37.40
# Epoch    28, train loss 0.103423, train error 0.65,  test loss 1.304220, test error 38.40
# Epoch    29, train loss 0.096972, train error 0.43,  test loss 1.306712, test error 38.00
# Epoch    30, train loss 0.092290, train error 0.43,  test loss 1.310097, test error 37.30
# Epoch    31, train loss 0.089664, train error 0.43,  test loss 1.317206, test error 37.70
# Epoch    32, train loss 0.087411, train error 0.38,  test loss 1.325596, test error 37.80
# Epoch    33, train loss 0.085431, train error 0.32,  test loss 1.330475, test error 37.30
# Epoch    34, train loss 0.083709, train error 0.30,  test loss 1.341875, test error 37.40
# Epoch    35, train loss 0.081461, train error 0.28,  test loss 1.335920, test error 37.30
# Epoch    36, train loss 0.079696, train error 0.28,  test loss 1.339976, test error 37.20
# Epoch    37, train loss 0.077601, train error 0.18,  test loss 1.353154, test error 37.40
# Epoch    38, train loss 0.076400, train error 0.22,  test loss 1.353454, test error 37.40
# Epoch    39, train loss 0.074995, train error 0.10,  test loss 1.369547, test error 37.50
# Epoch    40, train loss 0.073017, train error 0.15,  test loss 1.365904, test error 37.10
# Epoch    41, train loss 0.072065, train error 0.12,  test loss 1.368403, test error 37.20
# Epoch    42, train loss 0.071509, train error 0.15,  test loss 1.369636, test error 37.00
# Epoch    43, train loss 0.070561, train error 0.12,  test loss 1.370882, test error 37.20
# Epoch    44, train loss 0.069954, train error 0.15,  test loss 1.377954, test error 37.30
# Epoch    45, train loss 0.069045, train error 0.10,  test loss 1.379951, test error 37.10
# Epoch    46, train loss 0.068216, train error 0.12,  test loss 1.380018, test error 37.40
# Epoch    47, train loss 0.067567, train error 0.10,  test loss 1.386100, test error 37.10
# Epoch    48, train loss 0.066840, train error 0.10,  test loss 1.388268, test error 37.40
# Epoch    49, train loss 0.066127, train error 0.07,  test loss 1.386888, test error 37.20

# %% [markdown]
# **TODO**: Plot the resulting quantities:
# - Train errors
# - Test errors
# - Train losses
# - Test losses

# %%
# Your code here
plot_results(errors_train, errors_test, losses_train, losses_test)

# %% [markdown]
# ---
#
# ## Part 1.b)

# %% [markdown]
# Now let's increase the capacity of our model to have five hidden layers and re-run our experiment. Pay attention to what happens to the train and test curves.

# %% [markdown]
# **TODO:**
# Define a model with five hidden layers of size 100
# and ReLU activations between them

# %%
# Your code here:
model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o)
)

# %% [markdown]
# **TODO**: Train the model using the same code as above

# %%
# Your code here
errors_train, errors_test, losses_train, losses_test = train_model(model, data_loader, 50)
# Out:
# Epoch     0, train loss 1.650371, train error 66.55,  test loss 1.743820, test error 69.40
# Epoch     1, train loss 1.411203, train error 56.50,  test loss 1.538603, test error 61.80
# Epoch     2, train loss 1.209974, train error 46.72,  test loss 1.443347, test error 56.90
# Epoch     3, train loss 1.012349, train error 36.70,  test loss 1.277576, test error 51.00
# Epoch     4, train loss 0.905015, train error 33.53,  test loss 1.313767, test error 49.90
# Epoch     5, train loss 0.764231, train error 28.15,  test loss 1.177305, test error 45.20
# Epoch     6, train loss 0.655053, train error 23.53,  test loss 1.145640, test error 44.40
# Epoch     7, train loss 0.631020, train error 22.97,  test loss 1.190611, test error 43.20
# Epoch     8, train loss 0.492123, train error 18.30,  test loss 1.120250, test error 41.60
# Epoch     9, train loss 0.509095, train error 18.93,  test loss 1.267892, test error 40.60
# Epoch    10, train loss 0.230449, train error 6.95,  test loss 1.057273, test error 35.70
# Epoch    11, train loss 0.174880, train error 4.90,  test loss 1.215818, test error 36.30
# Epoch    12, train loss 0.123817, train error 2.72,  test loss 1.268283, test error 38.30
# Epoch    13, train loss 0.085827, train error 1.75,  test loss 1.295029, test error 35.90
# Epoch    14, train loss 0.062787, train error 0.82,  test loss 1.409246, test error 35.60
# Epoch    15, train loss 0.041577, train error 0.35,  test loss 1.428421, test error 36.30
# Epoch    16, train loss 0.032151, train error 0.25,  test loss 1.501358, test error 35.90
# Epoch    17, train loss 0.026324, train error 0.20,  test loss 1.519209, test error 35.70
# Epoch    18, train loss 0.016789, train error 0.00,  test loss 1.645013, test error 36.60
# Epoch    19, train loss 0.011665, train error 0.00,  test loss 1.683408, test error 35.70
# Epoch    20, train loss 0.009904, train error 0.00,  test loss 1.692947, test error 36.10
# Epoch    21, train loss 0.008998, train error 0.00,  test loss 1.722900, test error 36.10
# Epoch    22, train loss 0.008375, train error 0.00,  test loss 1.742130, test error 36.00
# Epoch    23, train loss 0.007719, train error 0.00,  test loss 1.763571, test error 36.40
# Epoch    24, train loss 0.007244, train error 0.00,  test loss 1.776092, test error 36.00
# Epoch    25, train loss 0.006760, train error 0.00,  test loss 1.788826, test error 35.80
# Epoch    26, train loss 0.006409, train error 0.00,  test loss 1.803593, test error 35.50
# Epoch    27, train loss 0.006071, train error 0.00,  test loss 1.825787, test error 35.80
# Epoch    28, train loss 0.005735, train error 0.00,  test loss 1.836486, test error 35.50
# Epoch    29, train loss 0.005428, train error 0.00,  test loss 1.854419, test error 35.50
# Epoch    30, train loss 0.005285, train error 0.00,  test loss 1.856158, test error 35.30
# Epoch    31, train loss 0.005154, train error 0.00,  test loss 1.861381, test error 35.50
# Epoch    32, train loss 0.005037, train error 0.00,  test loss 1.869088, test error 35.60
# Epoch    33, train loss 0.004928, train error 0.00,  test loss 1.875051, test error 35.60
# Epoch    34, train loss 0.004814, train error 0.00,  test loss 1.878668, test error 35.60
# Epoch    35, train loss 0.004716, train error 0.00,  test loss 1.887272, test error 35.70
# Epoch    36, train loss 0.004611, train error 0.00,  test loss 1.891151, test error 35.60
# Epoch    37, train loss 0.004519, train error 0.00,  test loss 1.898054, test error 35.70
# Epoch    38, train loss 0.004422, train error 0.00,  test loss 1.900645, test error 35.70
# Epoch    39, train loss 0.004335, train error 0.00,  test loss 1.907795, test error 35.60
# Epoch    40, train loss 0.004288, train error 0.00,  test loss 1.910264, test error 35.70
# Epoch    41, train loss 0.004248, train error 0.00,  test loss 1.913167, test error 35.70
# Epoch    42, train loss 0.004205, train error 0.00,  test loss 1.916314, test error 35.80
# Epoch    43, train loss 0.004164, train error 0.00,  test loss 1.918977, test error 35.70
# Epoch    44, train loss 0.004124, train error 0.00,  test loss 1.921106, test error 35.70
# Epoch    45, train loss 0.004085, train error 0.00,  test loss 1.923487, test error 35.70
# Epoch    46, train loss 0.004047, train error 0.00,  test loss 1.925852, test error 35.70
# Epoch    47, train loss 0.004009, train error 0.00,  test loss 1.928704, test error 35.80
# Epoch    48, train loss 0.003971, train error 0.00,  test loss 1.931264, test error 35.70
# Epoch    49, train loss 0.003934, train error 0.00,  test loss 1.933624, test error 35.70

# %% [markdown]
# **TODO**: Plot the results using the same code as above

# %%
# Your code here
plot_results(errors_train, errors_test, losses_train, losses_test)

# %% [markdown]
# ---
#
# ## Part 1.c)

# %% [markdown]
# Let's run one last experiment, this time with a simple linear model with **NO** hidden layers. In this case we will decrease the capacity of the model. Again, pay attention to what happens to the train and test curves.

# %% [markdown]
# **TODO:** Define a model with no hidden layers. This model should just be a linear layer that maps from the input dimension, `D_i` to the output dimension, `D_o`

# %%
# Your code here
model = nn.Sequential(
  nn.Linear(D_i, D_o)
)

# %% [markdown]
# **TODO**: Train the model using the same code as above

# %%
# Your code here
errors_train, errors_test, losses_train, losses_test = train_model(model, data_loader, 50)
# Out:
# Epoch     0, train loss 1.783235, train error 70.70,  test loss 1.815456, test error 74.20
# Epoch     1, train loss 1.690151, train error 67.38,  test loss 1.721800, test error 71.40
# Epoch     2, train loss 1.673431, train error 66.82,  test loss 1.731045, test error 70.90
# Epoch     3, train loss 1.649688, train error 66.43,  test loss 1.696192, test error 69.50
# Epoch     4, train loss 1.635246, train error 64.75,  test loss 1.688918, test error 69.50
# Epoch     5, train loss 1.631847, train error 65.00,  test loss 1.669763, test error 69.00
# Epoch     6, train loss 1.621652, train error 64.22,  test loss 1.682657, test error 70.20
# Epoch     7, train loss 1.626190, train error 64.55,  test loss 1.667829, test error 68.60
# Epoch     8, train loss 1.618718, train error 64.07,  test loss 1.673100, test error 69.70
# Epoch     9, train loss 1.623261, train error 64.80,  test loss 1.668239, test error 68.00
# Epoch    10, train loss 1.603548, train error 62.60,  test loss 1.668808, test error 69.40
# Epoch    11, train loss 1.601806, train error 62.75,  test loss 1.657310, test error 68.20
# Epoch    12, train loss 1.599659, train error 62.92,  test loss 1.655340, test error 66.50
# Epoch    13, train loss 1.598510, train error 62.78,  test loss 1.653750, test error 68.30
# Epoch    14, train loss 1.599256, train error 62.95,  test loss 1.659254, test error 68.20
# Epoch    15, train loss 1.596714, train error 63.33,  test loss 1.657725, test error 68.20
# Epoch    16, train loss 1.597049, train error 62.45,  test loss 1.658147, test error 67.40
# Epoch    17, train loss 1.599322, train error 62.40,  test loss 1.650614, test error 67.40
# Epoch    18, train loss 1.597933, train error 63.47,  test loss 1.658795, test error 67.70
# Epoch    19, train loss 1.596178, train error 63.00,  test loss 1.662264, test error 68.60
# Epoch    20, train loss 1.592805, train error 62.60,  test loss 1.654811, test error 67.90
# Epoch    21, train loss 1.592626, train error 63.15,  test loss 1.655312, test error 67.50
# Epoch    22, train loss 1.592849, train error 62.60,  test loss 1.653435, test error 66.70
# Epoch    23, train loss 1.592475, train error 62.30,  test loss 1.655461, test error 67.90
# Epoch    24, train loss 1.591894, train error 63.08,  test loss 1.658620, test error 68.60
# Epoch    25, train loss 1.591944, train error 63.00,  test loss 1.652254, test error 67.10
# Epoch    26, train loss 1.592289, train error 62.95,  test loss 1.656746, test error 67.70
# Epoch    27, train loss 1.591935, train error 62.55,  test loss 1.656708, test error 68.30
# Epoch    28, train loss 1.591756, train error 62.78,  test loss 1.656821, test error 66.90
# Epoch    29, train loss 1.592312, train error 63.17,  test loss 1.654665, test error 67.80
# Epoch    30, train loss 1.590212, train error 62.65,  test loss 1.654419, test error 67.40
# Epoch    31, train loss 1.590124, train error 62.35,  test loss 1.653603, test error 67.40
# Epoch    32, train loss 1.589956, train error 62.58,  test loss 1.653755, test error 67.90
# Epoch    33, train loss 1.589985, train error 62.62,  test loss 1.656661, test error 67.30
# Epoch    34, train loss 1.589808, train error 62.58,  test loss 1.654596, test error 67.50
# Epoch    35, train loss 1.589777, train error 62.72,  test loss 1.655541, test error 67.40
# Epoch    36, train loss 1.589757, train error 62.55,  test loss 1.653633, test error 67.70
# Epoch    37, train loss 1.589589, train error 62.35,  test loss 1.654193, test error 67.20
# Epoch    38, train loss 1.589533, train error 62.95,  test loss 1.652570, test error 67.70
# Epoch    39, train loss 1.589514, train error 62.95,  test loss 1.655679, test error 67.70
# Epoch    40, train loss 1.589389, train error 62.72,  test loss 1.654953, test error 67.40
# Epoch    41, train loss 1.589266, train error 62.75,  test loss 1.655192, test error 67.00
# Epoch    42, train loss 1.589264, train error 62.60,  test loss 1.654699, test error 67.40
# Epoch    43, train loss 1.589243, train error 62.47,  test loss 1.655432, test error 67.30
# Epoch    44, train loss 1.589217, train error 62.72,  test loss 1.654945, test error 67.40
# Epoch    45, train loss 1.589176, train error 62.62,  test loss 1.654101, test error 67.80
# Epoch    46, train loss 1.589119, train error 62.60,  test loss 1.654831, test error 67.10
# Epoch    47, train loss 1.589081, train error 62.58,  test loss 1.654797, test error 67.10
# Epoch    48, train loss 1.589060, train error 62.97,  test loss 1.654476, test error 67.00
# Epoch    49, train loss 1.589041, train error 62.67,  test loss 1.653793, test error 67.60

# %% [markdown]
# **TODO**: Plot the results using the same code as above

# %%
# Your code here
plot_results(errors_train, errors_test, losses_train, losses_test)

# %% [markdown]
# ---
#
# ## Part 1.d: Discussion

# %% [markdown]
# What did you observe as you changed the model capacity in your experiments? What are some measures you might include to improve generalization of your models?

# %%
# Your response here
"My response is below"
# Out:
# 'My response is below'

# %% [markdown]
# I created a neural model with one linear layer. This had the worst test error, train error, test loss, and test error. Then I made a neural model with 3 linear layers. All 4 measures improved and decreased after training for 50 epochs, however the test loss began to decrease and then increased. Then I made a model with 5 linear layers. Although the training error and training loss were decreased to 0, the test error and test loss were worse. The test loss started decreasing and then shot back up. I observed that there was a sweet spot in model capacity. A smaller capacity cannot represent the data as well, but too much capacity caused overfitting to the training data. One measure to improve generalization is simply to hone in on the sweet spot. Find which capacity works best. Another measure could be regularization. This would penalize large weights so that the model doesn't overfit nearly as bad. I could also add more training data. However it seems like what we talked about with the Bias Variance tradeoff.

# %% [markdown]
# ---
#
# # Q2:  Bias-variance Trade-off

# %% [markdown]
# In this problem, we will investigate the bias-variance trade-off and reproduce the curves seen in Figure 8.8 in Prince.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Let's specify the true function that we are trying to estimate, defined on [0,1]

# %%
def true_function(x):
    y = np.exp(np.sin(x*(2*3.1413)))
    return y

# %% [markdown]
# Now let's generate some data point and add bit of noise to the labels

# %%
def generate_data(n_data, sigma_y=0.3):
    # Generate x values quasi uniformly
    x = np.ones(n_data)
    for i in range(n_data):
        x[i] = np.random.uniform(i/n_data, (i+1)/n_data, 1)

    # y value from running through function and adding noise
    y = np.ones(n_data)
    for i in range(n_data):
        y[i] = true_function(x[i])
        y[i] += np.random.normal(0, sigma_y, 1)
    return x,y

# %% [markdown]
# Let's draw the fitted function, together with uncertainty used to generate points

# %%
def plot_function(x_func, y_func, x_data=None,y_data=None, x_model = None, y_model =None, sigma_func = None, sigma_model=None):

    fig,ax = plt.subplots()
    ax.plot(x_func, y_func, 'k-')
    if sigma_func is not None:
      ax.fill_between(x_func, y_func-2*sigma_func, y_func+2*sigma_func, color='lightgray')

    if x_data is not None:
        ax.plot(x_data, y_data, 'o', color='#d18362')

    if x_model is not None:
        ax.plot(x_model, y_model, '-', color='#7fe7de')

    if sigma_model is not None:
      ax.fill_between(x_model, y_model-2*sigma_model, y_model+2*sigma_model, color='lightgray')

    ax.set_xlim(0,1)
    ax.set_xlabel('Input, x')
    ax.set_ylabel('Output, y')
    plt.show()
    plt.show()

# %% [markdown]
# Sample from the true function (no noise):

# %%
x_func = np.linspace(0, 1.0, 100)
y_func = true_function(x_func);

# %% [markdown]
# Generate some training data (with noise):

# %%
np.random.seed(1)
sigma_func = 0.3
n_data = 15
x_data,y_data = generate_data(n_data, sigma_func)
# Out:
# /tmp/ipykernel_211/1973353951.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[i] = np.random.uniform(i/n_data, (i+1)/n_data, 1)
# /tmp/ipykernel_211/1973353951.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i] += np.random.normal(0, sigma_y, 1)

# %% [markdown]
# Plot the data with the functions defined above

# %%
plot_function(x_func, y_func, x_data, y_data, sigma_func=sigma_func)

# %%
# Define model -- beta is a scalar and omega has size n_hidden,1
def network(x, beta, omega):
    # Retrieve number of hidden units
    n_hidden = omega.shape[0]

    y = np.zeros_like(x)
    for c_hidden in range(n_hidden):
        # Evaluate activations based on shifted lines (figure 8.4b-d)
        line_vals =  x  - c_hidden/n_hidden
        h =  line_vals * (line_vals > 0)
        # Weight activations by omega parameters and sum
        y = y + omega[c_hidden] * h
    # Add bias, beta
    y = y + beta

    return y

# %%
# This fits the n_hidden+1 parameters (see fig 8.4a) in closed form.
# If you have studied linear algebra, then you will know it is a least
# squares solution of the form (A^TA)^-1A^Tb.  If you don't recognize that,
# then just take it on trust that this gives you the best possible solution.
def fit_model_closed_form(x,y,n_hidden):
  n_data = len(x)
  A = np.ones((n_data, n_hidden+1))
  for i in range(n_data):
      for j in range(1,n_hidden+1):
          A[i,j] = x[i]-(j-1)/n_hidden
          if A[i,j] < 0:
              A[i,j] = 0;

  beta_omega = np.linalg.lstsq(A, y, rcond=None)[0]

  beta = beta_omega[0]
  omega = beta_omega[1:]

  return beta, omega

# %%
# Closed form solution
beta, omega = fit_model_closed_form(x_data,y_data,n_hidden=3)

# Get prediction for model across graph range
x_model = np.linspace(0,1,100);
y_model = network(x_model, beta, omega)

# Draw the function and the model
plot_function(x_func, y_func, x_data,y_data, x_model, y_model)

# %% [markdown]
# ---
#
# ## Part 2.a) Estimating the mean and variance of the model outputs, over many training runs

# %% [markdown]
# **TODO:** Fill in the missing pieces of this function to run the model many times with different datasets and return the mean and variance

# %%
def get_model_mean_variance(n_data, n_datasets, n_hidden, sigma_func):

  # Create array that stores model results in rows
  y_model_all = np.zeros((n_datasets, n_data))

  for c_dataset in range(n_datasets):
    # TODO -- Generate n_data x,y, pairs with standard deviation sigma_func
    # Replace this line
    x_data, y_data = generate_data(n_data, sigma_func)

    # TODO -- Fit the model
    # Replace this line:
    beta, omega = fit_model_closed_form(x_data,y_data,n_hidden)

    # TODO -- Run the fitted model on x_model
    # Replace this line
    y_model = network(x_model, beta, omega)

    # Store the model results
    y_model_all[c_dataset,:] = y_model

  # Get mean and standard deviation of model
  mean_model = np.mean(y_model_all,axis=0)
  std_model = np.std(y_model_all,axis=0)

  # Return the mean and standard deviation of the fitted model
  return mean_model, std_model

# %% [markdown]
# Let's generate N=100 random data sets, fit the model N=100 times and look the mean and variance. Here we will have 15 data points and 3 hidden units in our model:

# %%
n_datasets = 100
n_data = 15
sigma_func = 0.3
n_hidden = 3

x_model = np.linspace(0,1,15);

# Get mean and variance of fitted model
np.random.seed(1)
mean_model, std_model = get_model_mean_variance(n_data, n_datasets, n_hidden, sigma_func)
# Out:
# /tmp/ipykernel_211/1973353951.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[i] = np.random.uniform(i/n_data, (i+1)/n_data, 1)
# /tmp/ipykernel_211/1973353951.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i] += np.random.normal(0, sigma_y, 1)

# %% [markdown]
# Plot the results

# %%
x_model_grid = np.linspace(0, 1, len(mean_model))
plot_function(x_func, y_func, x_model=x_model_grid, y_model=mean_model, sigma_model=std_model)

# %% [markdown]
# If you did this correctly, you can see that there that we observe both **bias** and **variance** in the model outputs. Here bias refers to the fact that we have some error from the model outputs and the true function (distance between cyan and black lines); variance refers to the gray region indicating there is a fair amount of variability in what the model outputs over each dataset it sees.

# %% [markdown]
# ---
#
# ## Part 2.b) Changing the amount of available data

# %% [markdown]
# **TODO**: Let's rerun the same experiment as the cell above, but this time let's increase the the number of training points to 100, `n_data=100`

# %%
n_datasets = 100
n_data = 100
sigma_func = 0.3
n_hidden = 3

x_model = np.linspace(0,1,100);

# Get mean and variance of fitted model
np.random.seed(1)
mean_model, std_model = get_model_mean_variance(n_data, n_datasets, n_hidden, sigma_func)
# Out:
# /tmp/ipykernel_211/1973353951.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[i] = np.random.uniform(i/n_data, (i+1)/n_data, 1)
# /tmp/ipykernel_211/1973353951.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i] += np.random.normal(0, sigma_y, 1)

# %% [markdown]
# **TODO**: Plot the results:

# %%
x_model_grid = np.linspace(0, 1, len(mean_model))
plot_function(x_func, y_func, x_model=x_model_grid, y_model=mean_model, sigma_model=std_model)

# %% [markdown]
# **TODO**: What happened to the variance? Record your observations

# %% [markdown]
# There is still a similar amount of bias between the two, but the variance is much smaller.

# %% [markdown]
# ---
#
# ## Part 2.c) Increasing the model capacity

# %% [markdown]
# **TODO**: Let's rerun the same experiment as the cell above, but this time let's increase set the number of hidden units to 12 and the number of training points to 15

# %%
n_datasets = 100
n_data = 15
sigma_func = 0.3
n_hidden = 12

x_model = np.linspace(0,1,15)

# Get mean and variance of fitted model
np.random.seed(1)
mean_model, std_model = get_model_mean_variance(n_data, n_datasets, n_hidden, sigma_func)
# Out:
# /tmp/ipykernel_211/1973353951.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[i] = np.random.uniform(i/n_data, (i+1)/n_data, 1)
# /tmp/ipykernel_211/1973353951.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i] += np.random.normal(0, sigma_y, 1)

# %% [markdown]
# **TODO**: Plot the results

# %%
x_model_grid = np.linspace(0, 1, len(mean_model))
plot_function(x_func, y_func, x_model=x_model_grid, y_model=mean_model, sigma_model=std_model)

# %% [markdown]
# **TODO**: What happened to the bias? Record your observations

# %% [markdown]
# Now there is little bias between the output function and the true function, but the variance is huge.

# %% [markdown]
# ---
#
# ## Part 2d) High capacity and high data

# %% [markdown]
# **TODO**: Let's rerun the same experiment as the cell above, but this time let's increase set the number of hidden units to 12 and the number of training points to 1000

# %%
n_datasets = 100
n_data = 1000
sigma_func = 0.3
n_hidden = 12

x_model = np.linspace(0,1,1000)

# Get mean and variance of fitted model
np.random.seed(1)
mean_model, std_model = get_model_mean_variance(n_data, n_datasets, n_hidden, sigma_func)
# Out:
# /tmp/ipykernel_211/1973353951.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[i] = np.random.uniform(i/n_data, (i+1)/n_data, 1)
# /tmp/ipykernel_211/1973353951.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i] += np.random.normal(0, sigma_y, 1)

# %% [markdown]
# **TODO:** Plot the results

# %%
x_model_grid = np.linspace(0, 1, len(mean_model))
plot_function(x_func, y_func, x_model=x_model_grid, y_model=mean_model, sigma_model=std_model)

# %% [markdown]
# **TODO**: Record your observations about the bias and variance in this setting

# %% [markdown]
# Both the bias and variance have decreased significantly to closely match the true function.

# %% [markdown]
# ---
#
# # Q3) L2 Regularization

# %% [markdown]
# This question investigates adding L2 regularization to the loss function for the Gabor model as in figure 9.1 of Prince

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap

# %% [markdown]
# Let's create our training data 30 pairs `{x_i, y_i}`. We'll try to fit the Gabor model to these data

# %%
data = np.array([[-1.920e+00,-1.422e+01,1.490e+00,-1.940e+00,-2.389e+00,-5.090e+00,
                 -8.861e+00,3.578e+00,-6.010e+00,-6.995e+00,3.634e+00,8.743e-01,
                 -1.096e+01,4.073e-01,-9.467e+00,8.560e+00,1.062e+01,-1.729e-01,
                  1.040e+01,-1.261e+01,1.574e-01,-1.304e+01,-2.156e+00,-1.210e+01,
                 -1.119e+01,2.902e+00,-8.220e+00,-1.179e+01,-8.391e+00,-4.505e+00],
                  [-1.051e+00,-2.482e-02,8.896e-01,-4.943e-01,-9.371e-01,4.306e-01,
                  9.577e-03,-7.944e-02 ,1.624e-01,-2.682e-01,-3.129e-01,8.303e-01,
                  -2.365e-02,5.098e-01,-2.777e-01,3.367e-01,1.927e-01,-2.222e-01,
                  6.352e-02,6.888e-03,3.224e-02,1.091e-02,-5.706e-01,-5.258e-02,
                  -3.666e-02,1.709e-01,-4.805e-02,2.008e-01,-1.904e-01,5.952e-01]])

# %% [markdown]
# ---
#
# ## Part 3.a) Setting up the Gabor Model

# %% [markdown]
# Gabor model definition

# %%
def model(phi,x):
  sin_component = np.sin(phi[0] + 0.06 * phi[1] * x)
  gauss_component = np.exp(-(phi[0] + 0.06 * phi[1] * x) * (phi[0] + 0.06 * phi[1] * x) / 32)
  y_pred= sin_component * gauss_component
  return y_pred

# %% [markdown]
# Let's define a function to plot the data, the model and its outputs:

# %%
def draw_model(data,model,phi,title=None):
  x_model = np.arange(-15,15,0.1)
  y_model = model(phi,x_model)

  fix, ax = plt.subplots()
  ax.plot(data[0,:],data[1,:],'bo')
  ax.plot(x_model,y_model,'m-')
  ax.set_xlim([-15,15]);ax.set_ylim([-1,1])
  ax.set_xlabel('x'); ax.set_ylabel('y')
  if title is not None:
    ax.set_title(title)
  plt.show()

# %% [markdown]
# Initialize the parameters

# %%
phi = np.zeros((2,1))
phi[0] =  -5     # Horizontal offset
phi[1] =  25     # Frequency

# %% [markdown]
# Draw the model:

# %%
draw_model(data,model,phi, "Initial parameters")

# %% [markdown]
# Now let's compute the sum of squares loss for the training data.

# %% [markdown]
#  **TODO:** Implement the sum of squares loss function

# %%
def compute_loss(data_x, data_y, model, phi):
  pred_y = model(phi, data_x)
  # TODO: add code here to compute the loss
  loss = np.sum((data_y - pred_y)**2)
  return loss

# %% [markdown]
# Now let's plot the whole loss function

# %%
# Define pretty colormap
my_colormap_vals_hex =('2a0902', '2b0a03', '2c0b04', '2d0c05', '2e0c06', '2f0d07', '300d08', '310e09', '320f0a', '330f0b', '34100b', '35110c', '36110d', '37120e', '38120f', '39130f', '3a1410', '3b1411', '3c1511', '3d1612', '3e1613', '3f1713', '401714', '411814', '421915', '431915', '451a16', '461b16', '471b17', '481c17', '491d18', '4a1d18', '4b1e19', '4c1f19', '4d1f1a', '4e201b', '50211b', '51211c', '52221c', '53231d', '54231d', '55241e', '56251e', '57261f', '58261f', '592720', '5b2821', '5c2821', '5d2922', '5e2a22', '5f2b23', '602b23', '612c24', '622d25', '632e25', '652e26', '662f26', '673027', '683027', '693128', '6a3229', '6b3329', '6c342a', '6d342a', '6f352b', '70362c', '71372c', '72372d', '73382e', '74392e', '753a2f', '763a2f', '773b30', '783c31', '7a3d31', '7b3e32', '7c3e33', '7d3f33', '7e4034', '7f4134', '804235', '814236', '824336', '834437', '854538', '864638', '874739', '88473a', '89483a', '8a493b', '8b4a3c', '8c4b3c', '8d4c3d', '8e4c3e', '8f4d3f', '904e3f', '924f40', '935041', '945141', '955242', '965343', '975343', '985444', '995545', '9a5646', '9b5746', '9c5847', '9d5948', '9e5a49', '9f5a49', 'a05b4a', 'a15c4b', 'a35d4b', 'a45e4c', 'a55f4d', 'a6604e', 'a7614e', 'a8624f', 'a96350', 'aa6451', 'ab6552', 'ac6552', 'ad6653', 'ae6754', 'af6855', 'b06955', 'b16a56', 'b26b57', 'b36c58', 'b46d59', 'b56e59', 'b66f5a', 'b7705b', 'b8715c', 'b9725d', 'ba735d', 'bb745e', 'bc755f', 'bd7660', 'be7761', 'bf7862', 'c07962', 'c17a63', 'c27b64', 'c27c65', 'c37d66', 'c47e67', 'c57f68', 'c68068', 'c78169', 'c8826a', 'c9836b', 'ca846c', 'cb856d', 'cc866e', 'cd876f', 'ce886f', 'ce8970', 'cf8a71', 'd08b72', 'd18c73', 'd28d74', 'd38e75', 'd48f76', 'd59077', 'd59178', 'd69279', 'd7937a', 'd8957b', 'd9967b', 'da977c', 'da987d', 'db997e', 'dc9a7f', 'dd9b80', 'de9c81', 'de9d82', 'df9e83', 'e09f84', 'e1a185', 'e2a286', 'e2a387', 'e3a488', 'e4a589', 'e5a68a', 'e5a78b', 'e6a88c', 'e7aa8d', 'e7ab8e', 'e8ac8f', 'e9ad90', 'eaae91', 'eaaf92', 'ebb093', 'ecb295', 'ecb396', 'edb497', 'eeb598', 'eeb699', 'efb79a', 'efb99b', 'f0ba9c', 'f1bb9d', 'f1bc9e', 'f2bd9f', 'f2bfa1', 'f3c0a2', 'f3c1a3', 'f4c2a4', 'f5c3a5', 'f5c5a6', 'f6c6a7', 'f6c7a8', 'f7c8aa', 'f7c9ab', 'f8cbac', 'f8ccad', 'f8cdae', 'f9ceb0', 'f9d0b1', 'fad1b2', 'fad2b3', 'fbd3b4', 'fbd5b6', 'fbd6b7', 'fcd7b8', 'fcd8b9', 'fcdaba', 'fddbbc', 'fddcbd', 'fddebe', 'fddfbf', 'fee0c1', 'fee1c2', 'fee3c3', 'fee4c5', 'ffe5c6', 'ffe7c7', 'ffe8c9', 'ffe9ca', 'ffebcb', 'ffeccd', 'ffedce', 'ffefcf', 'fff0d1', 'fff2d2', 'fff3d3', 'fff4d5', 'fff6d6', 'fff7d8', 'fff8d9', 'fffada', 'fffbdc', 'fffcdd', 'fffedf', 'ffffe0')
my_colormap_vals_dec = np.array([int(element,base=16) for element in my_colormap_vals_hex])
r = np.floor(my_colormap_vals_dec/(256*256))
g = np.floor((my_colormap_vals_dec - r *256 *256)/256)
b = np.floor(my_colormap_vals_dec - r * 256 *256 - g * 256)
my_colormap = ListedColormap(np.vstack((r,g,b)).transpose()/255.0)

def draw_loss_function(compute_loss, data,  model, my_colormap, phi_iters = None):

  # Make grid of offset/frequency values to plot
  offsets_mesh, freqs_mesh = np.meshgrid(np.arange(-10,10.0,0.1), np.arange(2.5,22.5,0.1))
  loss_mesh = np.zeros_like(freqs_mesh)
  # Compute loss for every set of parameters
  for idslope, slope in np.ndenumerate(freqs_mesh):
     loss_mesh[idslope] = compute_loss(data[0,:], data[1,:], model, np.array([[offsets_mesh[idslope]], [slope]]))

  fig,ax = plt.subplots()
  fig.set_size_inches(8,8)
  ax.contourf(offsets_mesh,freqs_mesh,loss_mesh,256,cmap=my_colormap)
  ax.contour(offsets_mesh,freqs_mesh,loss_mesh,20,colors=['#80808080'])
  if phi_iters is not None:
    ax.plot(phi_iters[0,:], phi_iters[1,:],'go-')
  ax.set_ylim([2.5,22.5])
  ax.set_xlabel('Offset $\phi_{0}$'); ax.set_ylabel('Frequency, $\phi_{1}$')
  plt.show()
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\p'
# <>:25: SyntaxWarning: invalid escape sequence '\p'
# <>:25: SyntaxWarning: invalid escape sequence '\p'
# <>:25: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_163/657524152.py:25: SyntaxWarning: invalid escape sequence '\p'
#   ax.set_xlabel('Offset $\phi_{0}$'); ax.set_ylabel('Frequency, $\phi_{1}$')
# /tmp/ipykernel_163/657524152.py:25: SyntaxWarning: invalid escape sequence '\p'
#   ax.set_xlabel('Offset $\phi_{0}$'); ax.set_ylabel('Frequency, $\phi_{1}$')

# %%
draw_loss_function(compute_loss, data, model, my_colormap)

# %% [markdown]
# Now let's compute the gradient vector for a given set of parameters:
#
# \begin{equation}
# \frac{\partial L}{\partial \boldsymbol\phi} = \begin{bmatrix}\frac{\partial L}{\partial \phi_0} \\\frac{\partial L}{\partial \phi_1} \end{bmatrix}.
# \end{equation}

# %% [markdown]
# The Gabor model has two parameters, $\phi_0$ and $\phi_1$. We need to comptue the deriviate of the loss (sum of squares) with respect both quantities. Below we define two functions that each implement of the two partial deriviates we need. This is a hassle to get right!

# %%
def gabor_deriv_phi0(data_x,data_y,phi0, phi1):
    x = 0.06 * phi1 * data_x + phi0
    y = data_y
    cos_component = np.cos(x)
    sin_component = np.sin(x)
    gauss_component = np.exp(-0.5 * x *x / 16)
    deriv = cos_component * gauss_component - sin_component * gauss_component * x / 16
    deriv = 2* deriv * (sin_component * gauss_component - y)
    return np.sum(deriv)

def gabor_deriv_phi1(data_x, data_y,phi0, phi1):
    x = 0.06 * phi1 * data_x + phi0
    y = data_y
    cos_component = np.cos(x)
    sin_component = np.sin(x)
    gauss_component = np.exp(-0.5 * x *x / 16)
    deriv = 0.06 * data_x * cos_component * gauss_component - 0.06 * data_x*sin_component * gauss_component * x / 16
    deriv = 2*deriv * (sin_component * gauss_component - y)
    return np.sum(deriv)

# %% [markdown]
# Now, let's implement a function that puts each partial deriviate into a vector, called a gradient:

# %%
def compute_gradient(data_x, data_y, phi):
    dl_dphi0 = gabor_deriv_phi0(data_x, data_y, phi[0],phi[1])
    dl_dphi1 = gabor_deriv_phi1(data_x, data_y, phi[0],phi[1])
    # Return the gradient
    return np.array([[dl_dphi0],[dl_dphi1]])

# %% [markdown]
# Now we are ready to find the minimum.  For simplicity, we'll just use regular (non-stochastic) gradient descent with a fixed learning rate.

# %% [markdown]
# **TODO:** Implement the gradient descent updates in the function below:

# %%
def gradient_descent_step(phi, data):
  # TODO: Implement the gradient descent step
  # Step 1:  Compute the gradient
  gradient = compute_gradient(data[0], data[1], phi)
  # Step 2:  Update the parameters -- note we want to search in the negative (downhill direction)
  alpha = 0.1 # learning rate
  phi = phi - alpha * gradient
  return phi

# %%
# Initialize the parameters
n_steps = 41
phi_all = np.zeros((2,n_steps+1))
phi_all[0,0] = 2.6
phi_all[1,0] = 8.5

# Measure loss and draw initial model
loss =  compute_loss(data[0,:], data[1,:], model, phi_all[:,0:1])
draw_model(data,model,phi_all[:,0:1], "Initial parameters, Loss = %f"%(loss))

for c_step in range (n_steps):
  # Do gradient descent step
  phi_all[:,c_step+1:c_step+2] = gradient_descent_step(phi_all[:,c_step:c_step+1],data)
  # Measure loss and draw model every 8th step
  if c_step % 8 == 0:
    loss =  compute_loss(data[0,:], data[1,:], model, phi_all[:,c_step+1:c_step+2])
    draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))

draw_loss_function(compute_loss, data, model, my_colormap, phi_all)

# %% [markdown]
# ---
#
# ## Part 3.b) Applying L2 Regularization

# %% [markdown]
# Unfortunately, when we start from this position, the solution descends to a local minimum and the final model doesn't fit well.<br><br>
#
# But what if we had some weak knowledge that the solution was in the vicinity of $\phi_0=0.0$, $\phi_{1} = 12.5$ (the center of the plot)?
#
# Let's add a term to the loss function that penalizes solutions that deviate from this point.
#
# \begin{equation}
# L'[\boldsymbol\phi] = L[\boldsymbol\phi]+ \lambda\cdot \Bigl(\phi_{0}^2+(\phi_1-12.5)^2\Bigr)
# \end{equation}
#
# where $\lambda$ controls the relative importance of the original loss and the regularization term

# %% [markdown]
# **TODO**: define a function that implements the L2 regularization term (term in large parentheses in the above equation)

# %%
# Computes the regularization term
def compute_reg_term(phi0,phi1):
  # TODO Replace this line
  reg_term = ((phi0**2) + (phi1 - 12.5)**2)
  return reg_term

# %% [markdown]
# **TODO**: Now define the whole loss function, which is the sum of squares plus $\lambda$ times the L2 regularizatoin term, or $L'[\phi]$ defined above

# %%
# Note I called the weighting lambda_ to avoid confusing it with python lambda functions
def compute_loss2(data_x, data_y, model, phi, lambda_):
  pred_y = model(phi, data_x)
  # TODO: define the loss function
  loss = compute_loss(data_x, data_y, model, phi) + lambda_ * compute_reg_term(phi[0], phi[1])
  return loss

# %% [markdown]
# Code to draw the regularization function:

# %%
def draw_reg_function():

  # Make grid of offset/frequency values to plot
  offsets_mesh, freqs_mesh = np.meshgrid(np.arange(-10,10.0,0.1), np.arange(2.5,22.5,0.1))
  loss_mesh = np.zeros_like(freqs_mesh)
  # Compute loss for every set of parameters
  for idslope, slope in np.ndenumerate(freqs_mesh):
     loss_mesh[idslope] = compute_reg_term(offsets_mesh[idslope], slope)

  fig,ax = plt.subplots()
  fig.set_size_inches(8,8)
  ax.contourf(offsets_mesh,freqs_mesh,loss_mesh,256,cmap=my_colormap)
  ax.contour(offsets_mesh,freqs_mesh,loss_mesh,20,colors=['#80808080'])
  ax.set_ylim([2.5,22.5])
  ax.set_xlabel('Offset $\phi_{0}$'); ax.set_ylabel('Frequency, $\phi_{1}$')
  plt.show()

# Draw the regularization function.  It should look similar to figure 9.1b
draw_reg_function()
# Out:
# <>:15: SyntaxWarning: invalid escape sequence '\p'
# <>:15: SyntaxWarning: invalid escape sequence '\p'
# <>:15: SyntaxWarning: invalid escape sequence '\p'
# <>:15: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_163/1424307422.py:15: SyntaxWarning: invalid escape sequence '\p'
#   ax.set_xlabel('Offset $\phi_{0}$'); ax.set_ylabel('Frequency, $\phi_{1}$')
# /tmp/ipykernel_163/1424307422.py:15: SyntaxWarning: invalid escape sequence '\p'
#   ax.set_xlabel('Offset $\phi_{0}$'); ax.set_ylabel('Frequency, $\phi_{1}$')

# %% [markdown]
# Code to draw loss function with regularization:

# %%
def draw_loss_function_reg(data,  model, lambda_, my_colormap, phi_iters = None):

  # Make grid of offset/frequency values to plot
  offsets_mesh, freqs_mesh = np.meshgrid(np.arange(-10,10.0,0.1), np.arange(2.5,22.5,0.1))
  loss_mesh = np.zeros_like(freqs_mesh)
  # Compute loss for every set of parameters
  for idslope, slope in np.ndenumerate(freqs_mesh):
     loss_mesh[idslope] = compute_loss2(data[0,:], data[1,:], model, np.array([[offsets_mesh[idslope]], [slope]]), lambda_)

  fig,ax = plt.subplots()
  fig.set_size_inches(8,8)
  ax.contourf(offsets_mesh,freqs_mesh,loss_mesh,256,cmap=my_colormap)
  ax.contour(offsets_mesh,freqs_mesh,loss_mesh,20,colors=['#80808080'])
  if phi_iters is not None:
    ax.plot(phi_iters[0,:], phi_iters[1,:],'go-')
  ax.set_ylim([2.5,22.5])
  ax.set_xlabel('Offset $\phi_{0}$'); ax.set_ylabel('Frequency, $\phi_{1}$')
  plt.show()

# This should look something like figure 9.1c
draw_loss_function_reg(data, model, 0.2, my_colormap)
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\p'
# <>:17: SyntaxWarning: invalid escape sequence '\p'
# <>:17: SyntaxWarning: invalid escape sequence '\p'
# <>:17: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_163/131454182.py:17: SyntaxWarning: invalid escape sequence '\p'
#   ax.set_xlabel('Offset $\phi_{0}$'); ax.set_ylabel('Frequency, $\phi_{1}$')
# /tmp/ipykernel_163/131454182.py:17: SyntaxWarning: invalid escape sequence '\p'
#   ax.set_xlabel('Offset $\phi_{0}$'); ax.set_ylabel('Frequency, $\phi_{1}$')
# /tmp/ipykernel_163/131454182.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   loss_mesh[idslope] = compute_loss2(data[0,:], data[1,:], model, np.array([[offsets_mesh[idslope]], [slope]]), lambda_)

# %% [markdown]
# Now we'll compute the derivatives $\frac{\partial L'}{\partial\phi_0}$ and $\frac{\partial L'}{\partial\phi_1}$ of the regularized loss function:
#
# \begin{equation}
# L'[\boldsymbol\phi] = L[\boldsymbol\phi]+ \lambda\cdot \Bigl(\phi_{0}^2+(\phi_1-12.5)^2\Bigr)
# \end{equation}
#
# so that we can perform gradient descent.

# %% [markdown]
# **TODO:** Implement the partial of deriviates each the regularized loss function

# %%
def compute_gradient2(data_x, data_y, phi, lambda_):
    # TODO: compute partial derivates of each phi here:
    dl_dphi0 = gabor_deriv_phi0(data_x, data_y, phi[0], phi[1])
    dl_dphi1 = gabor_deriv_phi1(data_x, data_y, phi[0], phi[1])
    # Return the gradient
    return np.array([[dl_dphi0], [dl_dphi1]])

# %% [markdown]
# **TODO:** Implement the gradient descent step with the regularized loss function

# %%
def gradient_descent_step2(phi, lambda_, data):
  # TODO: Implement gradient descent
  # Step 1:  Compute the gradient
  gradient = compute_gradient2(data[0], data[1], phi, lambda_)
  # Step 2:  Update the parameters -- note we want to search in the negative (downhill direction)
  alpha = 0.1
  phi = phi - alpha * gradient
  return phi

# %% [markdown]
# Finally, let's run gradient descent and draw the result

# %%
n_steps = 41
phi_all = np.zeros((2,n_steps+1))
phi_all[0,0] = 2.6
phi_all[1,0] = 8.5
lambda_ = 0.2

# Measure loss and draw initial model
loss =  compute_loss2(data[0,:], data[1,:], model, phi_all[:,0:1], lambda_)
draw_model(data,model,phi_all[:,0:1], "Initial parameters, Loss = %f"%(loss))

for c_step in range (n_steps):
  # Do gradient descent step
  phi_all[:,c_step+1:c_step+2] = gradient_descent_step2(phi_all[:,c_step:c_step+1],lambda_, data)
  # Measure loss and draw model every 8th step
  if c_step % 8 == 0:
    loss =  compute_loss2(data[0,:], data[1,:], model, phi_all[:,c_step+1:c_step+2], lambda_)
    draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))

draw_loss_function_reg(data, model, lambda_, my_colormap, phi_all)
# Out:
# /tmp/ipykernel_163/2724188971.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   draw_model(data,model,phi_all[:,0:1], "Initial parameters, Loss = %f"%(loss))
# /tmp/ipykernel_163/2724188971.py:17: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))
# /tmp/ipykernel_163/131454182.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   loss_mesh[idslope] = compute_loss2(data[0,:], data[1,:], model, np.array([[offsets_mesh[idslope]], [slope]]), lambda_)

# %% [markdown]
# You should see that the gradient descent algorithm now finds the correct minimum. By applying a tiny bit of domain knowledge (the parameter phi0 tends to be near zero and the parameter phi1 tends to be near 12.5), we get a better solution. However, the cost is that this solution is slightly biased towards this prior knowledge.

# %% [markdown]
# ---
#
# ## Part 3.c) Low regularization

# %% [markdown]
# Let's experiment with different values of the regularization weight `lambda_`. In this experiment. Set `lambda_=0.01`. What happens when the regularization value is small? What happens to the final loss value when we add the regularization term? Does it go up?  Go down?  Stay the same? Record your observations.

# %%
# TODO: your code here
n_steps = 41
phi_all = np.zeros((2,n_steps+1))
phi_all[0,0] = 2.6
phi_all[1,0] = 8.5
lambda_ = 0.1

# Measure loss and draw initial model
loss =  compute_loss2(data[0,:], data[1,:], model, phi_all[:,0:1], lambda_)
draw_model(data,model,phi_all[:,0:1], "Initial parameters, Loss = %f"%(loss))

for c_step in range (n_steps):
  # Do gradient descent step
  phi_all[:,c_step+1:c_step+2] = gradient_descent_step2(phi_all[:,c_step:c_step+1],lambda_, data)
  # Measure loss and draw model every 8th step
  if c_step % 8 == 0:
    loss =  compute_loss2(data[0,:], data[1,:], model, phi_all[:,c_step+1:c_step+2], lambda_)
    draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))

draw_loss_function_reg(data, model, lambda_, my_colormap, phi_all)
# Out:
# /tmp/ipykernel_163/2697584195.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   draw_model(data,model,phi_all[:,0:1], "Initial parameters, Loss = %f"%(loss))
# /tmp/ipykernel_163/2697584195.py:18: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))
# /tmp/ipykernel_163/131454182.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   loss_mesh[idslope] = compute_loss2(data[0,:], data[1,:], model, np.array([[offsets_mesh[idslope]], [slope]]), lambda_)

# %% [markdown]
# When the regularization term is smaller the final loss value decreases. It also changes the contour of the map for descent.

# %% [markdown]
# ---
#
# ## Part 3.d) High regularization

# %% [markdown]
# Now set `lambda_=1.0`. What happens when the regularization value is large. What happens to the final loss value when we add the regularization term? Does it go up?  Go down?  Stay the same? Record your observations.

# %%
# TODO: Your code here
n_steps = 41
phi_all = np.zeros((2,n_steps+1))
phi_all[0,0] = 2.6
phi_all[1,0] = 8.5
lambda_ = 1.0

# Measure loss and draw initial model
loss =  compute_loss2(data[0,:], data[1,:], model, phi_all[:,0:1], lambda_)
draw_model(data,model,phi_all[:,0:1], "Initial parameters, Loss = %f"%(loss))

for c_step in range (n_steps):
  # Do gradient descent step
  phi_all[:,c_step+1:c_step+2] = gradient_descent_step2(phi_all[:,c_step:c_step+1],lambda_, data)
  # Measure loss and draw model every 8th step
  if c_step % 8 == 0:
    loss =  compute_loss2(data[0,:], data[1,:], model, phi_all[:,c_step+1:c_step+2], lambda_)
    draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))

draw_loss_function_reg(data, model, lambda_, my_colormap, phi_all)
# Out:
# /tmp/ipykernel_163/93839015.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   draw_model(data,model,phi_all[:,0:1], "Initial parameters, Loss = %f"%(loss))
# /tmp/ipykernel_163/93839015.py:18: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))
# /tmp/ipykernel_163/131454182.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   loss_mesh[idslope] = compute_loss2(data[0,:], data[1,:], model, np.array([[offsets_mesh[idslope]], [slope]]), lambda_)

# %% [markdown]
# The larger the regularization term the worse the final loss value. It changes the map into one big convex bowl instead of having several minima.

# %% [markdown]
# ---
#
# # Q4) Overfitting to MNIST

# %% [markdown]
# In this question, we will train a ConvNet on the MNIST dataset. The model will contain many more parameters than data points. We will investigate how to address the overfitting problem with L2 regularization (weight decay)
#
# The MNISt dataset contains cropped images of handwritten digits from 0 to 9. Our task will be to classify the input image to the correct digit.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# %% [markdown]
# You will want to make sure that you're connected to a GPU instance for this lab.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device

# %% [markdown]
# Your device should be `device(type='cuda')`

# %% [markdown]
# Now let's specify our hyperparameters

# %%
# Hyperparameters
batch_size = 128
learning_rate = 0.001
num_epochs = 25

# %% [markdown]
# And setup our transforms. The following code will take an input image, cast it to a tensor and normalize it:

# %%
transform = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5,), (0.5,))
])

# %% [markdown]
# Let's download the MNIST dataset and create our dataloader object:

# %%
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transform, download=True)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transform, download=True)

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Let's write some code to visualize one of the images from the training set

# %%
plt.imshow(train_dataset.data[0], cmap='gray')
plt.title('%i' % train_dataset.targets[0])
plt.show()

# %% [markdown]
# Now let's plot a bunch of digits together so you get an idea of what the training data looks like:

# %%
figure = plt.figure(figsize=(10, 8))
cols, rows = 5, 5
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(train_dataset), size=(1,)).item()
    img, label = train_dataset[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(label)
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %% [markdown]
# ---
#
# ## Q4.a) Training a ConvNet on MNIST

# %% [markdown]
# **TODO**: Here we will specify our CNN model. You will need to create a model class, called `CNN`, which inherits from the `nn.Module` base class.
#
# The CNN should have the following components:
#
#
# *   A `Conv2D` layer with 1 input channel, 32 output channels, a kernel size of 2 a stride of 1, and a padding of 3 pixels
# *   After the first `Conv2D` layer you should apply a `ReLU` acvtivation
# *   Then apply `MaxPool2d` with a kernel size of 2
# *   Next, you'll apply a second `Conv2D` layer with input channel of 32, output channel of 64, kernel size of 3, stride of 1, and padding of 2
# *   Apply another `ReLU` activation
# *   Introduce another `MaxPool2d` again with a kernel size of 2
# *   Next, you will flatten the output of the maxpool layer into a tensor with dimensions `batch_size x (64 * 9 * 9)`, where 64 is the number of output channgel from the previous `Conv2D` layer and 9 is the remaining spatial dimensions after applying maxpooling.
# *   Next, introduce a linear layer that maps from `(64 * 9 * 9)` to 1000
# *   Finally, apply a final, linear layer that maps from `1000` hidden units to `10` the number of classes in the dataset
# *   Note: we do not need to apply the softmax operation because the `nn.CrossEntropyLoss()` module requires unscaled logits for numerical stability. We will apply the argmax function in the test loop to evaluate accuracy.
# *   If you have implemented your model correctly, you should have 5,213,666 total parameters

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        # TODO: Your code here

    def forward(self, x):
        # TODO: Your code here
        return output

# %% [markdown]
# Let's instantiate our model:

# %%
model = CNN().to(device)

# %% [markdown]
# And count the number of parameters:

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters())
num_params = count_parameters(model)

# %% [markdown]
# We've implemented a test to make sure you've implemented your model correctly:

# %%
assert num_params == 5213666, f"Expected 5213666, got {num_params} parameters"

# %%
print(f'Total number of parameters: {num_params}')

# %%
print(f"Number of training examples: {len(train_loader.dataset)}")

# %% [markdown]
# **TODO**: Compute the ratio of parameters to data:

# %%
# TODO: Fill this line here
ratio =  None

# %%
print("We have {:.2f}x more parameters than data points!".format(ratio))

# %% [markdown]
# **TODO**: Write 1-2 sentences explaining why the ratio of parameters to data points is difficult for learning?

# %% [markdown]
# Let's instantiate our optimizer and loss function:

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# Below is our training and test loop. Let's train our model to see what happens

# %%
# Train the model
total_step = len(train_loader)
trn_losses = []
test_losses = []
for epoch in range(num_epochs):
    print(f"Starting epoch: {epoch + 1}")
    epoch_loss = 0.0
    pbar = tqdm(enumerate(train_loader), total=len(train_loader))
    for i, (images, labels) in pbar:
        images = images.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss.detach().item()
        pbar.set_postfix({'loss': f'{loss.detach().item():.4f}', 'iteration': i+1})
    epoch_loss /= len(train_loader)
    trn_losses.append(epoch_loss)

    print("Starting test set loop")
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        total_test_loss = 0
        for images, labels in tqdm(test_loader, total=len(test_loader)):
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            test_loss = criterion(outputs, labels)
            total_test_loss += test_loss.detach().item()
        total_test_loss /= len(test_loader)
        print(f"Test Loss: {total_test_loss:.4f}, Test: Accuracy: {(correct/total):.4f}")
        test_losses.append(total_test_loss)

# %% [markdown]
# We are all done training. Let's visualize our train and test loss curves

# %%
plt.plot(np.arange(1, num_epochs+1), test_losses, linestyle='--', marker='o', label='TEST')
plt.plot(np.arange(1, num_epochs+1), trn_losses, linestyle='--', marker='o', label='TRAIN')

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Test Loss")
plt.legend()

plt.show()

# %% [markdown]
# **TODO:** What do you notice about the chart above? Is there a difference in the behavior of the train and test curves? If so, what is the difference and why do you think this is occuring?

# %% [markdown]
# ---
#
# ## Q4.b) Weight Decay

# %% [markdown]
# Now we apply L2 regularization (often called weight decay) to our training algorithm. Fortunately, this is quite easy with the `Adam` optimizer class in PyTorch.

# %% [markdown]
# **TODO**: Create a variable called `weight_decay` and set it to 0.001. Pass this into the `Adam` constructor and retrain your model

# %%
# Hyperparameters
batch_size = 128
learning_rate = 0.001
num_epochs = 25
# TODO: add your weight decay variable here

# %% [markdown]
# Let's re-instantiate our model:

# %%
model = CNN().to(device)

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# **TODO**: Instantiate your optimizer object with weight decay. See the docs if you have any question: https://pytorch.org/docs/stable/generated/torch.optim.Adam.html

# %%
# TODO: implement an adam optimizer with weight decay
optimizer = None

# %% [markdown]
# **TODO**: train your model with the same setup as before. However, this time create a new list of epoch-wise loss values for the train and the test loop. In other words, rename `trn_losses` --> `wd_train_losses` and test_losses --> `wd_test_losses`

# %%
# TODO: Train the model

# %% [markdown]
# Now let's plot the epoch-wise losses from our baseline experiment (with no weight decay) and the epoch-wise losses from our training run with weight decay:

# %%
plt.plot(np.arange(1, num_epochs+1), test_losses, linestyle='--', marker='o', label='TEST')
plt.plot(np.arange(1, num_epochs+1), trn_losses, linestyle='--', marker='o', label='TRAIN')

plt.plot(np.arange(1, num_epochs+1), wd_test_losses, linestyle='--', marker='o', label='TEST (weight decay)')
plt.plot(np.arange(1, num_epochs+1), wd_trn_losses, linestyle='--', marker='o', label='TRAIN (weight decay)')



plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Test Loss")
plt.legend()

plt.show()

# %% [markdown]
# **TODO**: Discuss your observations about 1) the behavior of the train loss in the baseline run vs the train loss in the weight decay run and 2) the behavior of the test loss in the baseline run vs the test loss of the weight decay run. Discuss whether or not you think applying weight decay was successful.
